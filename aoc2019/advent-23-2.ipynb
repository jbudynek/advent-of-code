1102,1,5,71,1102,2016,1,72,1105,1,73,1,1,33,103577,37,69302,13,922,14,12659,1,263919,1102,35573,1,66,1102,1,1,67,1102,2053,1,68,1102,556,1,69,1102,1,1,71,1102,1,2055,72,1106,0,73,1,-45,1,87973,1101,0,16567,66,1102,1,1,67,1101,2084,0,68,1102,556,1,69,1102,1,1,71,1102,2086,1,72,1105,1,73,1,2514,14,50636,1102,1,61169,66,1102,1,1,67,1102,2115,1,68,1102,556,1,69,1101,0,1,71,1101,0,2117,72,1106,0,73,1,-48,3,57194,1102,1,17377,66,1101,1,0,67,1101,0,2146,68,1102,556,1,69,1101,1,0,71,1101,0,2148,72,1106,0,73,1,2281,13,1383,1101,0,104677,66,1101,1,0,67,1102,2177,1,68,1101,0,556,69,1101,1,0,71,1101,2179,0,72,1106,0,73,1,125,38,195166,1102,83689,1,66,1101,2,0,67,1101,0,2208,68,1102,302,1,69,1102,1,1,71,1101,2212,0,72,1105,1,73,0,0,0,0,8,179782,1101,32969,0,66,1102,1,1,67,1101,2241,0,68,1102,1,556,69,1102,1,1,71,1102,1,2243,72,1105,1,73,1,75,41,371828]

# %%
# OPCODE INT MACHINE

def decode(c): # returns mode_a,mode_b,mode_c,opcode
    code_5="{:05d}".format(c)
    return int(code_5[0]),int(code_5[1]),int(code_5[2]),10*int(code_5[3])+int(code_5[4])

def code_to_dictcode(code):
    dictcode = {i: code[i] for i in range(0, len(code))}
    return dictcode

def get_dictcode(i, dictcode): # handle negative?
    if not i in dictcode:
        return 0
    return dictcode[i]

def set_dictcode(i, value, dictcode): # handle negative?
    dictcode[i] = value

# if one_output=True --> returns OUTPUT - array of outputs
# else
# returns output,dictcode,i,input_signals,input_index,relative_base
def opcode_machine(dictcode, i, input_signals,input_index,relative_base,one_output=True,DBG=False):
    
    code_i = get_dictcode(i,dictcode)
    mode_a,mode_b,mode_c,opcode = decode(code_i)
    
    output = []
    
    while(True):

        if (DBG==True): print(code_i,mode_a,mode_b,mode_c,opcode)
        
        if mode_c==0: # position mode
            i1=get_dictcode(i+1,dictcode)
        elif mode_c==1: # immediate mode
            i1=i+1
        elif mode_c==2: # relative mode
            i1=get_dictcode(i+1,dictcode)+relative_base

            
        if mode_b==0: # position mode
            i2=get_dictcode(i+2,dictcode)
        elif mode_b==1: # immediate mode
            i2=i+2
        elif mode_b==2: # relative mode
            i2=get_dictcode(i+2,dictcode)+relative_base
            
        if mode_a==0: # position mode
            i3=get_dictcode(i+3,dictcode)
        elif mode_a==1: # immediate mode
            i3=i+3
        elif mode_a==2: # relative mode
            i3=get_dictcode(i+3,dictcode)+relative_base
            
        code_i1 = get_dictcode(i1,dictcode)
        code_i2 = get_dictcode(i2,dictcode)
        code_i3 = get_dictcode(i3,dictcode)

        if (opcode==99):
            if (DBG==True): print("HALT")
            if (one_output):
                return ('HALT',dictcode,i,input_signals,input_index,relative_base)
            else:
                return output
        elif (opcode== 1): # addition
            set_dictcode(i3, code_i1+code_i2, dictcode)
            i = i +4
        elif (opcode == 2): # multiplication
            set_dictcode(i3, code_i1*code_i2, dictcode)
            i = i +4
        elif (opcode == 3): # input
            set_dictcode(i1, input_signals[input_index], dictcode)
            i = i+2
            if (input_index<len(input_signals)-1):
                input_index += 1
            else:
                input_index += 0
                #print("no more input signals")
                if (one_output):
                    return (output,dictcode,i,input_signals,input_index,relative_base)
        elif (opcode == 4): # output
            output = output + [code_i1]
            if (DBG==True): print(code_i1)
            i = i+2
            if (one_output):
                return (output,dictcode,i,input_signals,input_index,relative_base)
        elif (opcode == 5): #jump-if-true
            if code_i1!=0:
                i = code_i2
            else:
                i=i+3
        elif (opcode == 6): #jump-if-false
            if code_i1==0:
                i = code_i2
            else:
                i=i+3
        elif (opcode == 7): #less than
            if code_i1<code_i2:
                set_dictcode(i3,1,dictcode)
            else:
                set_dictcode(i3,0,dictcode)
            i = i+4
        elif (opcode == 8): #equals
            if code_i1==code_i2:
                set_dictcode(i3,1,dictcode)
            else:
                set_dictcode(i3,0,dictcode)
            i = i+4
        elif (opcode == 9): # relative base update
            relative_base += code_i1
            i = i+2
                
        if(DBG):
            print("i",i)
            print("relative_base",relative_base)
            print("dictcode",dictcode)
        code_i = get_dictcode(i,dictcode)
        mode_a,mode_b,mode_c,opcode = decode(code_i)

    # we never get there
    return "NEVER"

# %%
def create_world(nb_comp, code, DBG=True):
    #dictcode,i,input_signals,input_index,relative_base
    
    #dict of num -> (dictcode,i,input_signals,input_index,relative_base)
    computer = {}
    queue = {}
    outputs = {}
    dc = code_to_dictcode(code)
    output = 0
    for i in range(nb_comp):
        if DBG:print(i)
        computer[i] = [dc.copy(),0,[i],0,0]
        queue[i]=[]
        outputs[i]=[]
        if DBG:print(i,"OK")
        #boot
        output, computer[i][0], \
        computer[i][1], computer[i][2], \
        computer[i][3], computer[i][4] = opcode_machine(computer[i][0],computer[i][1],
                                             computer[i][2],computer[i][3],computer[i][4],
                                             one_output=True,DBG=False)
        if DBG:print(output,"output")
        if DBG:print(i,"BOOT OK")
    return computer,queue,outputs
            
def tick(computer, queue, outputs, DBG=True):
    nb_comp=len(computer)
    for i in range(nb_comp):
        if DBG:
            print("computer i=",i)
            print("queue[i]",queue[i])
            print("outputs[i]",outputs[i])
        
        
        # while something in the queue
            # get x, send x
            # get y, send y
            # continue until no output
        # continue until no output
        
        while(len(queue[i])>0):
            # pop x, y, send them, and loop until no output
            rec_x = queue[i].pop(0)
            rec_y = queue[i].pop(0)
            #send x
            computer[i][2] = [rec_x] 
            computer[i][3] = 0
            print("received ",rec_x," in ",i)
            output, computer[i][0], \
            computer[i][1], computer[i][2], \
            computer[i][3], computer[i][4] = opcode_machine(computer[i][0],computer[i][1],
                                             computer[i][2],computer[i][3],computer[i][4],
                                             one_output=True,DBG=False)
            if DBG:print("output after rec sent" , len(output),output)
            if (output!=[]): 
                outputs[i].append(output[0])
            #send y
            computer[i][2] = [rec_y] 
            computer[i][3] = 0
            print("received ",rec_y," in ",i)
            output, computer[i][0], \
            computer[i][1], computer[i][2], \
            computer[i][3], computer[i][4] = opcode_machine(computer[i][0],computer[i][1],
                                             computer[i][2],computer[i][3],computer[i][4],
                                             one_output=True,DBG=False)
            if DBG:print("output after rec sent" , len(output),output)
            if (output!=[]): 
                outputs[i].append(output[0])

            while (1):
                computer[i][2] = [-1]
                computer[i][3] = 0

                output, computer[i][0], \
                computer[i][1], computer[i][2], \
                computer[i][3], computer[i][4] = opcode_machine(computer[i][0],computer[i][1],
                                                 computer[i][2],computer[i][3],computer[i][4],
                                                 one_output=True,DBG=False)

                if DBG:print("output after -1" , len(output), output)
                if (output!=[]): 
                    outputs[i].append(output[0])
                else:
                    break
        # EMPTY QUEUE
        while (1):
            computer[i][2] = [-1]
            computer[i][3] = 0

            output, computer[i][0], \
            computer[i][1], computer[i][2], \
            computer[i][3], computer[i][4] = opcode_machine(computer[i][0],computer[i][1],
                                             computer[i][2],computer[i][3],computer[i][4],
                                             one_output=True,DBG=False)

            if DBG:print("output after -1" , len(output), output)
            if (output!=[]): 
                outputs[i].append(output[0])
            else:
                break

    return computer, queue, outputs

def test_idle(queue):
    for i in queue.keys():
        if i in queue and queue[i]!=[]: 
            return False
    return True

def function(DBG=True):
    computer,queue,outputs = create_world(50,puzzle_input,False) # 
    
    nat_packet_x = -1
    nat_packet_y = -1
    nb_idle=0
    for tt in range(1000):
        print("tick",tt)
        if DBG: print("*tick",tt,"idle",test_idle(queue), nb_idle)
        #print(queue)
        computer,queue,outputs = tick(computer,queue,outputs,False)
        #print(outputs)
        
        if (test_idle(queue) and test_idle(outputs)): nb_idle+=1
        else: nb_idle=0
            
        for outk in outputs.keys():
            if (DBG): print("outk",outk)
            out = outputs[outk]
            if (DBG): print("out",out)
            
            while (len(out)>0):
                destination = out.pop(0)
                packet_x=out.pop(0)
                packet_y=out.pop(0)
                if (destination == 255):
                    print("*** append",packet_x," - ",packet_y," to NAT")
                    nat_packet_x = packet_x
                    nat_packet_y = packet_y
                else:
                    queue[destination].append(packet_x)
                    queue[destination].append(packet_y)
                    print(outk,"appended ",packet_x," - ",packet_y," to ",destination)
                    
        if (test_idle(queue) and test_idle(outputs)): nb_idle+=1
        else: nb_idle=0
        if (nb_idle>=3 and nat_packet_x!=-1 and nat_packet_y!=-1):
            nb_idle=0
            if DBG: print("idle - nat_packet",nat_packet_x," - ",nat_packet_y)
            print("*** NAT appended ",nat_packet_x," - ",nat_packet_y," to ",0)
            queue[0].append(nat_packet_x)
            queue[0].append(nat_packet_y)
    return 0

function(False)
# Out:
# tick 0
# tick 1
# 0 appended  89891  -  26006  to  8
# 0 appended  38546  -  26006  to  2
# 0 appended  57819  -  26006  to  2
# 0 appended  98269  -  26006  to  17
# 0 appended  196538  -  26006  to  17
# 0 appended  294807  -  26006  to  17
# 6 appended  185914  -  5  to  41
# 6 appended  29191  -  5  to  12
# 6 appended  83689  -  5  to  21
# 6 appended  97583  -  5  to  38
# 6 appended  292749  -  5  to  38
# 6 appended  187988  -  5  to  5
# 7 appended  464785  -  3  to  41
# 7 appended  226749  -  3  to  44
# 7 appended  302332  -  3  to  44
# 9 appended  50636  -  2514  to  14
# 11 appended  278871  -  -1193  to  41
# 16 appended  1844  -  2368  to  13
# 18 appended  37977  -  43  to  14
# 19 appended  12979  -  56158  to  48
# 22 appended  103577  -  1  to  33
# 22 appended  69302  -  1  to  37
# 22 appended  922  -  1  to  13
# 22 appended  12659  -  1  to  14
# 22 appended  263919  -  1  to  1
# 23 appended  390332  -  10  to  38
# 23 appended  93994  -  10  to  5
# ...
